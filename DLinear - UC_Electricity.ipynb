# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import random
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# Torch libraries
#
import torch
import torch.nn                     as nn
import torch.nn.functional          as F
from   torch.utils.data             import DataLoader
from   torch.utils.data             import Dataset


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# User libraries
#
from utils.PerformanceMetrics import RegressionEvaluation
from utils.EarlyStopping      import *
from utils.LRScheduler        import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## CUDA

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.2.0
# 12.1
# True

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    print(f"[INFO] Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device('cpu')
    print("[INFO] Using CPU")
# Out:
# [INFO] Using GPU: NVIDIA GeForce GTX 1660 SUPER

# %% [markdown]
# ## Neural networks parameters

# %%
class Parameters():
    def __init__(self):
        self.description = 'DLinear model for time-series forecasting'
        self.model_name = 'DLinear'
        
        # =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
        # Neural network model parameters
        #
        # Input sequence length - look-back
        self.Lag         = 96
        # Prediction sequence length
        self.Horizon     = 96
        #
        self.individual  = False
        self.enc_in      = 1
        self.kernel_size = 25
        
        # Training parameters
        #
        # Number of epochs
        self.epochs        = 1000
        # Batch size
        self.batch_size    = 32
        # Number of workers in DataLoader
        self.num_workers   = 0
        # Define verbose
        self.verbose       = True
        # Learning rate
        self.learning_rate = 1e-4
        # Trained model path
        self.model_path    = 'models/electricity/DLinear_0.pth'
        
        # Data handling
        #
        # Filename
        self.filename              = './data/Electricity/Electricity.csv'
        # Target series name 
        self.targetSeries          = '0'
        # Training-set percentage
        self.TrainingSetPercentage = 0.8
        # Data Log-transformation
        self.Transformation        = True
        # Scaling {'Standard', 'MinMax', 'Robust'}
        self.Scaling               = 'Standard'

args = Parameters()

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( args.filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))

df.head(3)
# Out:
# [INFO] Data imported
# [INFO] Time: 1.11 seconds
#                   date     0     1      2      3      4       5     6       7  \
# 0  2016-07-01 02:00:00  14.0  69.0  234.0  415.0  215.0  1056.0  29.0   840.0
# 1  2016-07-01 03:00:00  18.0  92.0  312.0  556.0  292.0  1363.0  29.0  1102.0
# 2  2016-07-01 04:00:00  21.0  96.0  312.0  560.0  272.0  1240.0  29.0  1025.0
#
#        8  ...    311    312      313     314     315   316   317     318  \
# 0  226.0  ...  676.0  372.0  80100.0  4719.0  5002.0  48.0  38.0  1558.0
# 1  271.0  ...  805.0  452.0  95200.0  4643.0  6617.0  65.0  47.0  2177.0
# 2  270.0  ...  817.0  430.0  96600.0  4285.0  6571.0  64.0  43.0  2193.0
#
#      319      OT
# 0  182.0  2162.0
# 1  253.0  2835.0
# 2  218.0  2764.0
#
# [3 rows x 322 columns]

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['date'] = df['date'].astype('datetime64[ns]')

# Set index
#
df.set_index('date', inplace=True)


# Keep only selected time-series
#
df = pd.DataFrame( df[ [ args.targetSeries ] ] )


df.head( 3 )
# Out:
#                         0
# date
# 2016-07-01 02:00:00  14.0
# 2016-07-01 03:00:00  18.0
# 2016-07-01 04:00:00  21.0

# %% [markdown]
# ### H and windows_complexity

# %%
from H_estimation.LZ1 import *
from H_estimation.LZ2 import *
from H_estimation.compute_PIMax import *

# %%
series = df[args.targetSeries].values
epsilon = [0.1]
for e in epsilon:
    N = (max(series)-min(series)+2*e)/e
    H = Compute_LZ2(series,e)
    Pi_max = get_pimax(H,N)
    print(f"Epsilon: {e}, Entropy: {H:.4f}, Pi_max: {Pi_max:.4f}")
# Out:
# Epsilon: 0.1, Entropy: 2.9034, Pi_max: 0.7927

# %%
def window_wise_complexity(x, P, F, stride=1):
    """Compute window-wise complexity using FFT variance."""
    L = P + F
    if len(x) < L:
        return np.nan  # 序列太短
    windows = [x[i:i+L] for i in range(0, len(x)-L+1, stride)]
    A = np.array([np.abs(np.fft.fft(w)) for w in windows])
    mean_A = np.mean(A, axis=0)
    diff = A - mean_A
    complexity = np.mean(np.sum(diff**2, axis=1))
    return complexity

# %%
window_complexity = window_wise_complexity(series, args.Lag, args.Horizon)
print(f"Window-wise Complexity: {window_complexity:.4f}")
# Out:
# Window-wise Complexity: 17830151.2252

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * args.TrainingSetPercentage )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train[ args.targetSeries ].plot(ax=ax, color='tab:blue' )
df_test[ args.targetSeries ].plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], frameon = False, fontsize = 14)
plt.ylabel(args.targetSeries, size = 14)
plt.xlabel('Date', size = 14);
plt.xticks(size = 12);
plt.yticks(size = 12);

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-args.Lag:], df_test])

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Data Transformation

# %%
if (args.Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    VALUE = np.ceil( max(abs( -df.min().min() ), 1.0) )
    
    df_train = np.log( df_train + VALUE)
    df_test  = np.log( df_test  + VALUE)
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %%
if (args.Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    for feature in df.columns:
        if (feature ==  args.targetSeries ): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = MinMaxScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = MinMaxScaler()
    df[ args.targetSeries ] = scaler.fit_transform( df[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_train[ args.targetSeries ] = scaler.fit_transform( df_train[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_test[ args.targetSeries ]  = scaler.transform( df_test[  args.targetSeries  ].to_numpy().reshape(-1,1) )
            
elif (args.Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    for feature in df.columns:
        if (feature ==  args.targetSeries ): continue
        print('Feature: ', feature)        
        # Set scaler
        #
        scaler = RobustScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = RobustScaler()
    df[ args.targetSeries ] = scaler.fit_transform( df[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_train[ args.targetSeries ] = scaler.fit_transform( df_train[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_test[ args.targetSeries ]  = scaler.transform( df_test[  args.targetSeries  ].to_numpy().reshape(-1,1) )
        
elif (args.Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    for feature in df.columns:
        if (feature ==  args.targetSeries ): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df[ args.targetSeries ] = scaler.fit_transform( df[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_train[ args.targetSeries ] = scaler.fit_transform( df_train[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_test[ args.targetSeries ]  = scaler.transform( df_test[  args.targetSeries  ].to_numpy().reshape(-1,1) )             
else:
    print('[WARNING] Unknown data scaling. Standar scaling was selected')   
    
    for feature in df.columns:
        if (feature ==  args.targetSeries ): continue
        print('Feature: ', feature)
        # Set scaler
        #
        scaler = StandardScaler()
        
        df_train[feature] = scaler.fit_transform( df_train[ feature ].to_numpy().reshape(-1,1) )
        df_test[feature]  = scaler.transform( df_test[ feature ].to_numpy().reshape(-1,1) )

        
    # Scaling of Target Series
    #
    scaler = StandardScaler()
    df[ args.targetSeries ] = scaler.fit_transform( df[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_train[ args.targetSeries ] = scaler.fit_transform( df_train[  args.targetSeries  ].to_numpy().reshape(-1,1) )
    df_test[ args.targetSeries ]  = scaler.transform( df_test[  args.targetSeries  ].to_numpy().reshape(-1,1) )
# Out:
# [INFO] Scaling: Standard

# %%
series = df[args.targetSeries].values

# %%
window_complexity = window_wise_complexity(series, args.Lag, args.Horizon)
print(f"Window-wise Complexity: {window_complexity:.4f}")
# Out:
# Window-wise Complexity: 14770.7814

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 1, targetSeries = None, overlap = 1):
    
    if (targetSeries is None):
        targetSeries = df.columns[-1]
    
    dataX, dataY, dataDate = [], [], []
    
    for i in tqdm( range(0, df.shape[0] + 1  - Lag - Horizon, overlap) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ targetSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        dataDate.append( df.index[i + Lag : i + Lag + Horizon].tolist() )
        
    return ( np.array(dataX), np.array(dataY), np.array(dataDate) )

# %%
trainX, trainY, _ = create_dataset(df           = df_train, 
                                   Lag          = args.Lag, 
                                   Horizon      = args.Horizon, 
                                   targetSeries = args.targetSeries,
                                   overlap      = 1,)
                               

testX,  testY, testDate  = create_dataset(df           = df_test, 
                                          Lag          = args.Lag, 
                                          Horizon      = args.Horizon, 
                                          targetSeries = args.targetSeries,
                                          overlap      = 1,)


# Last 10% of the training data will be used for validation
#
idx = int(0.9 * trainX.shape[0])
validX, validY = trainX[ idx: ], trainY[ idx: ]
trainX, trainY = trainX[ :idx ], trainY[ :idx ]

print('Training data shape:   ', trainX.shape, trainY.shape)
print('Validation data shape: ', validX.shape, validY.shape)
print('Testing data shape:    ', testX.shape,  testY.shape)
# Out:
#   0%|          | 0/20852 [00:00<?, ?it/s]
# 100%|██████████| 20852/20852 [00:03<00:00, 6475.12it/s]
# 100%|██████████| 5166/5166 [00:00<00:00, 9807.86it/s]
# Training data shape:    (18766, 96, 1) (18766, 96)
# Validation data shape:  (2086, 96, 1) (2086, 96)
# Testing data shape:     (5166, 96, 1) (5166, 96)

# %%
# Reshaping
#
trainY = np.expand_dims(trainY, axis = -1)
validY = np.expand_dims(validY, axis = -1)
testY  = np.expand_dims(testY,  axis = -1)

# %%
class Data( Dataset ):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, idx):
        return self.X[ idx ], self.Y[ idx ]
    

    
# Create training and test dataloaders
#
train_ds = Data(trainX, trainY)
valid_ds = Data(validX, validY)
test_ds  = Data(testX,  testY)


# Prepare Data-Loaders
#
train_dl = DataLoader(train_ds, batch_size = args.batch_size, num_workers = args.num_workers)
valid_dl = DataLoader(valid_ds, batch_size = args.batch_size, num_workers = args.num_workers)
test_dl  = DataLoader(test_ds,  batch_size = args.batch_size, num_workers = args.num_workers)
#
print('[INFO] Data loaders were created')
# Out:
# [INFO] Data loaders were created

# %% [markdown]
# # Forecasting model: DLinear

# %%
class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x


class series_decomp(nn.Module):
    """
    Series decomposition block
    """
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class Model(nn.Module):
    """
    DLinear
    """
    def __init__(self, configs):
        super(Model, self).__init__()
        self.Lag  = configs.Lag
        self.Horizon = configs.Horizon

        # Decompsition Kernel Size
        kernel_size       = configs.kernel_size
        self.decompsition = series_decomp(kernel_size)
        self.individual   = configs.individual
        self.channels     = configs.enc_in

        if self.individual:
            self.Linear_Seasonal = nn.ModuleList()
            self.Linear_Trend    = nn.ModuleList()
            self.Linear_Decoder  = nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Seasonal.append(nn.Linear(self.Lag,self.Horizon))
                self.Linear_Seasonal[i].weight = nn.Parameter((1/self.Lag)*torch.ones([self.Horizon,self.Lag]))
                self.Linear_Trend.append(nn.Linear(self.Lag,self.Horizon))
                self.Linear_Trend[i].weight = nn.Parameter((1/self.Lag)*torch.ones([self.Horizon,self.Lag]))
                self.Linear_Decoder.append(nn.Linear(self.Lag,self.Horizon))
        else:
            self.Linear_Seasonal = nn.Linear(self.Lag,self.Horizon)
            self.Linear_Trend = nn.Linear(self.Lag,self.Horizon)
            self.Linear_Decoder = nn.Linear(self.Lag,self.Horizon)
            self.Linear_Seasonal.weight = nn.Parameter((1/self.Lag)*torch.ones([self.Horizon,self.Lag]))
            self.Linear_Trend.weight = nn.Parameter((1/self.Lag)*torch.ones([self.Horizon,self.Lag]))

    def forward(self, x):
        # x: [Batch, Input length, Channel]
        seasonal_init, trend_init = self.decompsition(x)
        seasonal_init, trend_init = seasonal_init.permute(0,2,1), trend_init.permute(0,2,1)
        if self.individual:
            seasonal_output = torch.zeros([seasonal_init.size(0),seasonal_init.size(1),self.Horizon],dtype=seasonal_init.dtype).to(seasonal_init.device)
            trend_output = torch.zeros([trend_init.size(0),trend_init.size(1),self.Horizon],dtype=trend_init.dtype).to(trend_init.device)
            for i in range(self.channels):
                seasonal_output[:,i,:] = self.Linear_Seasonal[i](seasonal_init[:,i,:])
                trend_output[:,i,:] = self.Linear_Trend[i](trend_init[:,i,:])
        else:
            seasonal_output = self.Linear_Seasonal(seasonal_init)
            trend_output = self.Linear_Trend(trend_init)

        x = seasonal_output + trend_output
        return x.permute(0,2,1) # to [Batch, Output length, Channel]

# %% [markdown]
# ## Setup model

# %%
# Initialize Neural Network
# 
model = Model( args )

model.to( device )


print( model )
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=96, out_features=96, bias=True)
#   (Linear_Trend): Linear(in_features=96, out_features=96, bias=True)
#   (Linear_Decoder): Linear(in_features=96, out_features=96, bias=True)
# )

# %% [markdown]
# ## Training parameters

# %%
# Specify loss function
#
criterion = nn.MSELoss()

# Specify loss function
#
optimizer = torch.optim.Adam(params = model.parameters(), 
                             lr     = args.learning_rate)




# Early stopping
#
early_stopping = EarlyStopping(patience  = 100,
                               min_delta = 1e-5)


# LR scheduler
#
scheduler = LRScheduler(optimizer = optimizer, 
                        patience  = 50, 
                        min_lr    = 1e-10, 
                        factor    = 0.5, 
                        verbose   = args.verbose)

# %% [markdown]
# ## Training process

# %%
# Store training and validation loss
Loss = {
         'Train': [], 
         'Valid':  []
       }



# Set number at how many iteration the training process (results) will be provided
#
batch_show = (train_dl.dataset.__len__() // args. batch_size // 5)



# Main loop - Training process
#
for epoch in range(1, args.epochs+1):

    # Start timer
    start = time.time()
    
    # Monitor training loss
    #
    train_loss = 0.0
    valid_loss  = 0.0    
    
    
    
    ###################
    # Train the model #
    ###################
    batch_idx = 0
    for data, target in train_dl:
        
        # Clear the gradients of all optimized variables
        #
        optimizer.zero_grad()
        
        # Forward pass: compute predicted outputs by passing inputs to the model
        #
        if (device.type == 'cpu'):
            data   = torch.tensor(data,   dtype=torch.float32)
            target = torch.tensor(target, dtype=torch.float32)
        else:
            data   = torch.tensor(data,   dtype=torch.float32).cuda()
            target = torch.tensor(target, dtype=torch.float32).cuda()

            
        outputs = model( data )
        

        
        # Calculate the loss
        #
        loss = criterion(outputs, target)
        
        
        
        # Backward pass: compute gradient of the loss with respect to model parameters
        #
        loss.backward()
        
        
        
        # Perform a single optimization step (parameter update)
        #
        optimizer.step()
        
        
        
        # Update running training loss
        #
        train_loss += loss.item()*data.size(0)
               
        # Increase batch_idx
        #
        batch_idx  += 1
        
        
        # Info
        #
        if (args.verbose == True and batch_idx % batch_show == 0):
            print('> Epoch: {} [{:5.0f}/{} ({:.0f}%)]'.format(epoch, batch_idx * len(data), len(train_dl.dataset), 100. * batch_idx / len(train_dl)))        

           
        
    # Print avg training statistics 
    #
    train_loss = train_loss / train_dl.dataset.X.shape[0]

    
    
    
    
    with torch.no_grad():
        for data, target in valid_dl:

            # Forward pass: compute predicted outputs by passing inputs to the model
            #
            if (device.type == 'cpu'):
                data   = torch.tensor(data, dtype=torch.float32)
                target = torch.tensor(target, dtype=torch.float32)
            else:
                data   = torch.tensor(data, dtype=torch.float32).cuda()
                target = torch.tensor(target, dtype=torch.float32).cuda()


            outputs = model( data )
        
          

            # Calculate the loss
            #
            loss = criterion(outputs, target)
                
            # update running training loss
            valid_loss += loss.item()*data.size(0)
              

    # Print avg training statistics 
    #
    valid_loss = valid_loss / test_dl.dataset.X.shape[0]






    # Stop timer
    #
    stop  = time.time()
    
    
    # Show training results
    #
    print('\n[INFO] Train Loss: {:.6f}\tValid Loss: {:.6f} \tTime: {:.2f}secs'.format(train_loss, valid_loss, stop-start), end=' ')

   
    

    # Update best model
    #
    if (epoch == 1):
        Best_score = valid_loss
        
        torch.save(model.state_dict(), args.model_path)
        print('(Model saved)\n')
    else:
        if (Best_score > valid_loss):
            Best_score = valid_loss
            
            torch.save(model.state_dict(), args.model_path)
            print('(Model saved)\n')
        else:
            print('\n')
     
    
    # Store train/val loss
    #
    Loss['Train'] += [ train_loss ]
    Loss['Valid'] += [ valid_loss ]
    

    
    
    
    # =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
    # Learning rate scheduler
    #
    scheduler( valid_loss )
    
    
    # =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
    # Early Stopping
    #
    if ( early_stopping( valid_loss ) ): break
# Out:
# > Epoch: 1 [ 3744/18766 (20%)]
# > Epoch: 1 [ 7488/18766 (40%)]
# > Epoch: 1 [11232/18766 (60%)]
# > Epoch: 1 [14976/18766 (80%)]
# > Epoch: 1 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.516368	Valid Loss: 0.354380 	Time: 1.26secs (Model saved)
#
# > Epoch: 2 [ 3744/18766 (20%)]
# > Epoch: 2 [ 7488/18766 (40%)]
# > Epoch: 2 [11232/18766 (60%)]
# > Epoch: 2 [14976/18766 (80%)]
# > Epoch: 2 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.485921	Valid Loss: 0.352030 	Time: 1.21secs (Model saved)
#
# > Epoch: 3 [ 3744/18766 (20%)]
# > Epoch: 3 [ 7488/18766 (40%)]
# > Epoch: 3 [11232/18766 (60%)]
# > Epoch: 3 [14976/18766 (80%)]
# > Epoch: 3 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.473473	Valid Loss: 0.351643 	Time: 1.37secs (Model saved)
#
# > Epoch: 4 [ 3744/18766 (20%)]
# > Epoch: 4 [ 7488/18766 (40%)]
# > Epoch: 4 [11232/18766 (60%)]
# > Epoch: 4 [14976/18766 (80%)]
# > Epoch: 4 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.466518	Valid Loss: 0.351852 	Time: 1.39secs
#
# > Epoch: 5 [ 3744/18766 (20%)]
# > Epoch: 5 [ 7488/18766 (40%)]
# > Epoch: 5 [11232/18766 (60%)]
# > Epoch: 5 [14976/18766 (80%)]
# > Epoch: 5 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.462211	Valid Loss: 0.352349 	Time: 1.41secs
#
# > Epoch: 6 [ 3744/18766 (20%)]
# > Epoch: 6 [ 7488/18766 (40%)]
# > Epoch: 6 [11232/18766 (60%)]
# > Epoch: 6 [14976/18766 (80%)]
# > Epoch: 6 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.459411	Valid Loss: 0.352980 	Time: 1.44secs
#
# > Epoch: 7 [ 3744/18766 (20%)]
# > Epoch: 7 [ 7488/18766 (40%)]
# > Epoch: 7 [11232/18766 (60%)]
# > Epoch: 7 [14976/18766 (80%)]
# > Epoch: 7 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.457531	Valid Loss: 0.353653 	Time: 1.41secs
#
# > Epoch: 8 [ 3744/18766 (20%)]
# > Epoch: 8 [ 7488/18766 (40%)]
# > Epoch: 8 [11232/18766 (60%)]
# > Epoch: 8 [14976/18766 (80%)]
# > Epoch: 8 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.456234	Valid Loss: 0.354310 	Time: 1.38secs
#
# > Epoch: 9 [ 3744/18766 (20%)]
# > Epoch: 9 [ 7488/18766 (40%)]
# > Epoch: 9 [11232/18766 (60%)]
# > Epoch: 9 [14976/18766 (80%)]
# > Epoch: 9 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.455318	Valid Loss: 0.354925 	Time: 1.38secs
#
# > Epoch: 10 [ 3744/18766 (20%)]
# > Epoch: 10 [ 7488/18766 (40%)]
# > Epoch: 10 [11232/18766 (60%)]
# > Epoch: 10 [14976/18766 (80%)]
# > Epoch: 10 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.454656	Valid Loss: 0.355487 	Time: 1.38secs
#
# > Epoch: 11 [ 3744/18766 (20%)]
# > Epoch: 11 [ 7488/18766 (40%)]
# > Epoch: 11 [11232/18766 (60%)]
# > Epoch: 11 [14976/18766 (80%)]
# > Epoch: 11 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.454168	Valid Loss: 0.355992 	Time: 1.40secs
#
# > Epoch: 12 [ 3744/18766 (20%)]
# > Epoch: 12 [ 7488/18766 (40%)]
# > Epoch: 12 [11232/18766 (60%)]
# > Epoch: 12 [14976/18766 (80%)]
# > Epoch: 12 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.453802	Valid Loss: 0.356444 	Time: 1.41secs
#
# > Epoch: 13 [ 3744/18766 (20%)]
# > Epoch: 13 [ 7488/18766 (40%)]
# > Epoch: 13 [11232/18766 (60%)]
# > Epoch: 13 [14976/18766 (80%)]
# > Epoch: 13 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.453522	Valid Loss: 0.356846 	Time: 1.41secs
#
# > Epoch: 14 [ 3744/18766 (20%)]
# > Epoch: 14 [ 7488/18766 (40%)]
# > Epoch: 14 [11232/18766 (60%)]
# > Epoch: 14 [14976/18766 (80%)]
# > Epoch: 14 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.453306	Valid Loss: 0.357205 	Time: 1.43secs
#
# > Epoch: 15 [ 3744/18766 (20%)]
# > Epoch: 15 [ 7488/18766 (40%)]
# > Epoch: 15 [11232/18766 (60%)]
# > Epoch: 15 [14976/18766 (80%)]
# > Epoch: 15 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.453136	Valid Loss: 0.357524 	Time: 1.41secs
#
# > Epoch: 16 [ 3744/18766 (20%)]
# > Epoch: 16 [ 7488/18766 (40%)]
# > Epoch: 16 [11232/18766 (60%)]
# > Epoch: 16 [14976/18766 (80%)]
# > Epoch: 16 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.453002	Valid Loss: 0.357809 	Time: 1.51secs
#
# > Epoch: 17 [ 3744/18766 (20%)]
# > Epoch: 17 [ 7488/18766 (40%)]
# > Epoch: 17 [11232/18766 (60%)]
# > Epoch: 17 [14976/18766 (80%)]
# > Epoch: 17 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452894	Valid Loss: 0.358064 	Time: 1.41secs
#
# > Epoch: 18 [ 3744/18766 (20%)]
# > Epoch: 18 [ 7488/18766 (40%)]
# > Epoch: 18 [11232/18766 (60%)]
# > Epoch: 18 [14976/18766 (80%)]
# > Epoch: 18 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452807	Valid Loss: 0.358292 	Time: 1.45secs
#
# > Epoch: 19 [ 3744/18766 (20%)]
# > Epoch: 19 [ 7488/18766 (40%)]
# > Epoch: 19 [11232/18766 (60%)]
# > Epoch: 19 [14976/18766 (80%)]
# > Epoch: 19 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452736	Valid Loss: 0.358498 	Time: 1.44secs
#
# > Epoch: 20 [ 3744/18766 (20%)]
# > Epoch: 20 [ 7488/18766 (40%)]
# > Epoch: 20 [11232/18766 (60%)]
# > Epoch: 20 [14976/18766 (80%)]
# > Epoch: 20 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452678	Valid Loss: 0.358683 	Time: 1.44secs
#
# > Epoch: 21 [ 3744/18766 (20%)]
# > Epoch: 21 [ 7488/18766 (40%)]
# > Epoch: 21 [11232/18766 (60%)]
# > Epoch: 21 [14976/18766 (80%)]
# > Epoch: 21 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452630	Valid Loss: 0.358849 	Time: 1.39secs
#
# > Epoch: 22 [ 3744/18766 (20%)]
# > Epoch: 22 [ 7488/18766 (40%)]
# > Epoch: 22 [11232/18766 (60%)]
# > Epoch: 22 [14976/18766 (80%)]
# > Epoch: 22 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452591	Valid Loss: 0.359000 	Time: 1.42secs
#
# > Epoch: 23 [ 3744/18766 (20%)]
# > Epoch: 23 [ 7488/18766 (40%)]
# > Epoch: 23 [11232/18766 (60%)]
# > Epoch: 23 [14976/18766 (80%)]
# > Epoch: 23 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452558	Valid Loss: 0.359137 	Time: 1.41secs
#
# > Epoch: 24 [ 3744/18766 (20%)]
# > Epoch: 24 [ 7488/18766 (40%)]
# > Epoch: 24 [11232/18766 (60%)]
# > Epoch: 24 [14976/18766 (80%)]
# > Epoch: 24 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452531	Valid Loss: 0.359260 	Time: 1.45secs
#
# > Epoch: 25 [ 3744/18766 (20%)]
# > Epoch: 25 [ 7488/18766 (40%)]
# > Epoch: 25 [11232/18766 (60%)]
# > Epoch: 25 [14976/18766 (80%)]
# > Epoch: 25 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452508	Valid Loss: 0.359373 	Time: 1.38secs
#
# > Epoch: 26 [ 3744/18766 (20%)]
# > Epoch: 26 [ 7488/18766 (40%)]
# > Epoch: 26 [11232/18766 (60%)]
# > Epoch: 26 [14976/18766 (80%)]
# > Epoch: 26 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452488	Valid Loss: 0.359475 	Time: 1.37secs
#
# > Epoch: 27 [ 3744/18766 (20%)]
# > Epoch: 27 [ 7488/18766 (40%)]
# > Epoch: 27 [11232/18766 (60%)]
# > Epoch: 27 [14976/18766 (80%)]
# > Epoch: 27 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452472	Valid Loss: 0.359567 	Time: 1.40secs
#
# > Epoch: 28 [ 3744/18766 (20%)]
# > Epoch: 28 [ 7488/18766 (40%)]
# > Epoch: 28 [11232/18766 (60%)]
# > Epoch: 28 [14976/18766 (80%)]
# > Epoch: 28 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452458	Valid Loss: 0.359652 	Time: 1.40secs
#
# > Epoch: 29 [ 3744/18766 (20%)]
# > Epoch: 29 [ 7488/18766 (40%)]
# > Epoch: 29 [11232/18766 (60%)]
# > Epoch: 29 [14976/18766 (80%)]
# > Epoch: 29 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452446	Valid Loss: 0.359728 	Time: 1.39secs
#
# > Epoch: 30 [ 3744/18766 (20%)]
# > Epoch: 30 [ 7488/18766 (40%)]
# > Epoch: 30 [11232/18766 (60%)]
# > Epoch: 30 [14976/18766 (80%)]
# > Epoch: 30 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452436	Valid Loss: 0.359798 	Time: 1.37secs
#
# > Epoch: 31 [ 3744/18766 (20%)]
# > Epoch: 31 [ 7488/18766 (40%)]
# > Epoch: 31 [11232/18766 (60%)]
# > Epoch: 31 [14976/18766 (80%)]
# > Epoch: 31 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452427	Valid Loss: 0.359862 	Time: 1.41secs
#
# > Epoch: 32 [ 3744/18766 (20%)]
# > Epoch: 32 [ 7488/18766 (40%)]
# > Epoch: 32 [11232/18766 (60%)]
# > Epoch: 32 [14976/18766 (80%)]
# > Epoch: 32 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452420	Valid Loss: 0.359920 	Time: 1.39secs
#
# > Epoch: 33 [ 3744/18766 (20%)]
# > Epoch: 33 [ 7488/18766 (40%)]
# > Epoch: 33 [11232/18766 (60%)]
# > Epoch: 33 [14976/18766 (80%)]
# > Epoch: 33 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452414	Valid Loss: 0.359973 	Time: 1.39secs
#
# > Epoch: 34 [ 3744/18766 (20%)]
# > Epoch: 34 [ 7488/18766 (40%)]
# > Epoch: 34 [11232/18766 (60%)]
# > Epoch: 34 [14976/18766 (80%)]
# > Epoch: 34 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452408	Valid Loss: 0.360021 	Time: 1.37secs
#
# > Epoch: 35 [ 3744/18766 (20%)]
# > Epoch: 35 [ 7488/18766 (40%)]
# > Epoch: 35 [11232/18766 (60%)]
# > Epoch: 35 [14976/18766 (80%)]
# > Epoch: 35 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452403	Valid Loss: 0.360065 	Time: 1.32secs
#
# > Epoch: 36 [ 3744/18766 (20%)]
# > Epoch: 36 [ 7488/18766 (40%)]
# > Epoch: 36 [11232/18766 (60%)]
# > Epoch: 36 [14976/18766 (80%)]
# > Epoch: 36 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452399	Valid Loss: 0.360105 	Time: 1.41secs
#
# > Epoch: 37 [ 3744/18766 (20%)]
# > Epoch: 37 [ 7488/18766 (40%)]
# > Epoch: 37 [11232/18766 (60%)]
# > Epoch: 37 [14976/18766 (80%)]
# > Epoch: 37 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452396	Valid Loss: 0.360142 	Time: 1.38secs
#
# > Epoch: 38 [ 3744/18766 (20%)]
# > Epoch: 38 [ 7488/18766 (40%)]
# > Epoch: 38 [11232/18766 (60%)]
# > Epoch: 38 [14976/18766 (80%)]
# > Epoch: 38 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452393	Valid Loss: 0.360175 	Time: 1.35secs
#
# > Epoch: 39 [ 3744/18766 (20%)]
# > Epoch: 39 [ 7488/18766 (40%)]
# > Epoch: 39 [11232/18766 (60%)]
# > Epoch: 39 [14976/18766 (80%)]
# > Epoch: 39 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452390	Valid Loss: 0.360206 	Time: 1.37secs
#
# > Epoch: 40 [ 3744/18766 (20%)]
# > Epoch: 40 [ 7488/18766 (40%)]
# > Epoch: 40 [11232/18766 (60%)]
# > Epoch: 40 [14976/18766 (80%)]
# > Epoch: 40 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452388	Valid Loss: 0.360234 	Time: 1.38secs
#
# > Epoch: 41 [ 3744/18766 (20%)]
# > Epoch: 41 [ 7488/18766 (40%)]
# > Epoch: 41 [11232/18766 (60%)]
# > Epoch: 41 [14976/18766 (80%)]
# > Epoch: 41 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452386	Valid Loss: 0.360259 	Time: 1.46secs
#
# > Epoch: 42 [ 3744/18766 (20%)]
# > Epoch: 42 [ 7488/18766 (40%)]
# > Epoch: 42 [11232/18766 (60%)]
# > Epoch: 42 [14976/18766 (80%)]
# > Epoch: 42 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452384	Valid Loss: 0.360283 	Time: 1.46secs
#
# > Epoch: 43 [ 3744/18766 (20%)]
# > Epoch: 43 [ 7488/18766 (40%)]
# > Epoch: 43 [11232/18766 (60%)]
# > Epoch: 43 [14976/18766 (80%)]
# > Epoch: 43 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452382	Valid Loss: 0.360304 	Time: 1.46secs
#
# > Epoch: 44 [ 3744/18766 (20%)]
# > Epoch: 44 [ 7488/18766 (40%)]
# > Epoch: 44 [11232/18766 (60%)]
# > Epoch: 44 [14976/18766 (80%)]
# > Epoch: 44 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452381	Valid Loss: 0.360323 	Time: 1.38secs
#
# > Epoch: 45 [ 3744/18766 (20%)]
# > Epoch: 45 [ 7488/18766 (40%)]
# > Epoch: 45 [11232/18766 (60%)]
# > Epoch: 45 [14976/18766 (80%)]
# > Epoch: 45 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452380	Valid Loss: 0.360341 	Time: 1.39secs
#
# > Epoch: 46 [ 3744/18766 (20%)]
# > Epoch: 46 [ 7488/18766 (40%)]
# > Epoch: 46 [11232/18766 (60%)]
# > Epoch: 46 [14976/18766 (80%)]
# > Epoch: 46 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452378	Valid Loss: 0.360357 	Time: 1.41secs
#
# > Epoch: 47 [ 3744/18766 (20%)]
# > Epoch: 47 [ 7488/18766 (40%)]
# > Epoch: 47 [11232/18766 (60%)]
# > Epoch: 47 [14976/18766 (80%)]
# > Epoch: 47 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452378	Valid Loss: 0.360372 	Time: 1.50secs
#
# > Epoch: 48 [ 3744/18766 (20%)]
# > Epoch: 48 [ 7488/18766 (40%)]
# > Epoch: 48 [11232/18766 (60%)]
# > Epoch: 48 [14976/18766 (80%)]
# > Epoch: 48 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452377	Valid Loss: 0.360385 	Time: 1.45secs
#
# > Epoch: 49 [ 3744/18766 (20%)]
# > Epoch: 49 [ 7488/18766 (40%)]
# > Epoch: 49 [11232/18766 (60%)]
# > Epoch: 49 [14976/18766 (80%)]
# > Epoch: 49 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452376	Valid Loss: 0.360398 	Time: 1.47secs
#
# > Epoch: 50 [ 3744/18766 (20%)]
# > Epoch: 50 [ 7488/18766 (40%)]
# > Epoch: 50 [11232/18766 (60%)]
# > Epoch: 50 [14976/18766 (80%)]
# > Epoch: 50 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452375	Valid Loss: 0.360409 	Time: 1.45secs
#
# > Epoch: 51 [ 3744/18766 (20%)]
# > Epoch: 51 [ 7488/18766 (40%)]
# > Epoch: 51 [11232/18766 (60%)]
# > Epoch: 51 [14976/18766 (80%)]
# > Epoch: 51 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452375	Valid Loss: 0.360419 	Time: 1.42secs
#
# > Epoch: 52 [ 3744/18766 (20%)]
# > Epoch: 52 [ 7488/18766 (40%)]
# > Epoch: 52 [11232/18766 (60%)]
# > Epoch: 52 [14976/18766 (80%)]
# > Epoch: 52 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452374	Valid Loss: 0.360429 	Time: 1.44secs
#
# > Epoch: 53 [ 3744/18766 (20%)]
# > Epoch: 53 [ 7488/18766 (40%)]
# > Epoch: 53 [11232/18766 (60%)]
# > Epoch: 53 [14976/18766 (80%)]
# > Epoch: 53 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452374	Valid Loss: 0.360437 	Time: 1.43secs
#
# > Epoch: 54 [ 3744/18766 (20%)]
# > Epoch: 54 [ 7488/18766 (40%)]
# > Epoch: 54 [11232/18766 (60%)]
# > Epoch: 54 [14976/18766 (80%)]
# > Epoch: 54 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.452373	Valid Loss: 0.360445 	Time: 1.47secs
#
# > Epoch: 55 [ 3744/18766 (20%)]
# > Epoch: 55 [ 7488/18766 (40%)]
# > Epoch: 55 [11232/18766 (60%)]
# > Epoch: 55 [14976/18766 (80%)]
# > Epoch: 55 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448473	Valid Loss: 0.360294 	Time: 1.47secs
#
# > Epoch: 56 [ 3744/18766 (20%)]
# > Epoch: 56 [ 7488/18766 (40%)]
# > Epoch: 56 [11232/18766 (60%)]
# > Epoch: 56 [14976/18766 (80%)]
# > Epoch: 56 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448432	Valid Loss: 0.360219 	Time: 1.40secs
#
# > Epoch: 57 [ 3744/18766 (20%)]
# > Epoch: 57 [ 7488/18766 (40%)]
# > Epoch: 57 [11232/18766 (60%)]
# > Epoch: 57 [14976/18766 (80%)]
# > Epoch: 57 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448416	Valid Loss: 0.360153 	Time: 1.37secs
#
# > Epoch: 58 [ 3744/18766 (20%)]
# > Epoch: 58 [ 7488/18766 (40%)]
# > Epoch: 58 [11232/18766 (60%)]
# > Epoch: 58 [14976/18766 (80%)]
# > Epoch: 58 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448409	Valid Loss: 0.360097 	Time: 1.48secs
#
# > Epoch: 59 [ 3744/18766 (20%)]
# > Epoch: 59 [ 7488/18766 (40%)]
# > Epoch: 59 [11232/18766 (60%)]
# > Epoch: 59 [14976/18766 (80%)]
# > Epoch: 59 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448406	Valid Loss: 0.360052 	Time: 1.46secs
#
# > Epoch: 60 [ 3744/18766 (20%)]
# > Epoch: 60 [ 7488/18766 (40%)]
# > Epoch: 60 [11232/18766 (60%)]
# > Epoch: 60 [14976/18766 (80%)]
# > Epoch: 60 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448404	Valid Loss: 0.360017 	Time: 1.47secs
#
# > Epoch: 61 [ 3744/18766 (20%)]
# > Epoch: 61 [ 7488/18766 (40%)]
# > Epoch: 61 [11232/18766 (60%)]
# > Epoch: 61 [14976/18766 (80%)]
# > Epoch: 61 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448402	Valid Loss: 0.359990 	Time: 1.58secs
#
# > Epoch: 62 [ 3744/18766 (20%)]
# > Epoch: 62 [ 7488/18766 (40%)]
# > Epoch: 62 [11232/18766 (60%)]
# > Epoch: 62 [14976/18766 (80%)]
# > Epoch: 62 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448401	Valid Loss: 0.359970 	Time: 1.48secs
#
# > Epoch: 63 [ 3744/18766 (20%)]
# > Epoch: 63 [ 7488/18766 (40%)]
# > Epoch: 63 [11232/18766 (60%)]
# > Epoch: 63 [14976/18766 (80%)]
# > Epoch: 63 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448400	Valid Loss: 0.359954 	Time: 1.33secs
#
# > Epoch: 64 [ 3744/18766 (20%)]
# > Epoch: 64 [ 7488/18766 (40%)]
# > Epoch: 64 [11232/18766 (60%)]
# > Epoch: 64 [14976/18766 (80%)]
# > Epoch: 64 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448400	Valid Loss: 0.359943 	Time: 1.49secs
#
# > Epoch: 65 [ 3744/18766 (20%)]
# > Epoch: 65 [ 7488/18766 (40%)]
# > Epoch: 65 [11232/18766 (60%)]
# > Epoch: 65 [14976/18766 (80%)]
# > Epoch: 65 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448399	Valid Loss: 0.359934 	Time: 1.42secs
#
# > Epoch: 66 [ 3744/18766 (20%)]
# > Epoch: 66 [ 7488/18766 (40%)]
# > Epoch: 66 [11232/18766 (60%)]
# > Epoch: 66 [14976/18766 (80%)]
# > Epoch: 66 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448399	Valid Loss: 0.359927 	Time: 1.32secs
#
# > Epoch: 67 [ 3744/18766 (20%)]
# > Epoch: 67 [ 7488/18766 (40%)]
# > Epoch: 67 [11232/18766 (60%)]
# > Epoch: 67 [14976/18766 (80%)]
# > Epoch: 67 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448398	Valid Loss: 0.359921 	Time: 1.41secs
#
# > Epoch: 68 [ 3744/18766 (20%)]
# > Epoch: 68 [ 7488/18766 (40%)]
# > Epoch: 68 [11232/18766 (60%)]
# > Epoch: 68 [14976/18766 (80%)]
# > Epoch: 68 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448398	Valid Loss: 0.359917 	Time: 1.45secs
#
# > Epoch: 69 [ 3744/18766 (20%)]
# > Epoch: 69 [ 7488/18766 (40%)]
# > Epoch: 69 [11232/18766 (60%)]
# > Epoch: 69 [14976/18766 (80%)]
# > Epoch: 69 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448397	Valid Loss: 0.359914 	Time: 1.45secs
#
# > Epoch: 70 [ 3744/18766 (20%)]
# > Epoch: 70 [ 7488/18766 (40%)]
# > Epoch: 70 [11232/18766 (60%)]
# > Epoch: 70 [14976/18766 (80%)]
# > Epoch: 70 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448397	Valid Loss: 0.359911 	Time: 1.38secs
#
# > Epoch: 71 [ 3744/18766 (20%)]
# > Epoch: 71 [ 7488/18766 (40%)]
# > Epoch: 71 [11232/18766 (60%)]
# > Epoch: 71 [14976/18766 (80%)]
# > Epoch: 71 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448396	Valid Loss: 0.359908 	Time: 1.54secs
#
# > Epoch: 72 [ 3744/18766 (20%)]
# > Epoch: 72 [ 7488/18766 (40%)]
# > Epoch: 72 [11232/18766 (60%)]
# > Epoch: 72 [14976/18766 (80%)]
# > Epoch: 72 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448396	Valid Loss: 0.359906 	Time: 1.34secs
#
# > Epoch: 73 [ 3744/18766 (20%)]
# > Epoch: 73 [ 7488/18766 (40%)]
# > Epoch: 73 [11232/18766 (60%)]
# > Epoch: 73 [14976/18766 (80%)]
# > Epoch: 73 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448396	Valid Loss: 0.359904 	Time: 1.48secs
#
# > Epoch: 74 [ 3744/18766 (20%)]
# > Epoch: 74 [ 7488/18766 (40%)]
# > Epoch: 74 [11232/18766 (60%)]
# > Epoch: 74 [14976/18766 (80%)]
# > Epoch: 74 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448396	Valid Loss: 0.359902 	Time: 1.49secs
#
# > Epoch: 75 [ 3744/18766 (20%)]
# > Epoch: 75 [ 7488/18766 (40%)]
# > Epoch: 75 [11232/18766 (60%)]
# > Epoch: 75 [14976/18766 (80%)]
# > Epoch: 75 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448395	Valid Loss: 0.359901 	Time: 1.41secs
#
# > Epoch: 76 [ 3744/18766 (20%)]
# > Epoch: 76 [ 7488/18766 (40%)]
# > Epoch: 76 [11232/18766 (60%)]
# > Epoch: 76 [14976/18766 (80%)]
# > Epoch: 76 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448395	Valid Loss: 0.359899 	Time: 1.31secs
#
# > Epoch: 77 [ 3744/18766 (20%)]
# > Epoch: 77 [ 7488/18766 (40%)]
# > Epoch: 77 [11232/18766 (60%)]
# > Epoch: 77 [14976/18766 (80%)]
# > Epoch: 77 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448395	Valid Loss: 0.359898 	Time: 1.37secs
#
# > Epoch: 78 [ 3744/18766 (20%)]
# > Epoch: 78 [ 7488/18766 (40%)]
# > Epoch: 78 [11232/18766 (60%)]
# > Epoch: 78 [14976/18766 (80%)]
# > Epoch: 78 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448395	Valid Loss: 0.359897 	Time: 1.56secs
#
# > Epoch: 79 [ 3744/18766 (20%)]
# > Epoch: 79 [ 7488/18766 (40%)]
# > Epoch: 79 [11232/18766 (60%)]
# > Epoch: 79 [14976/18766 (80%)]
# > Epoch: 79 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359895 	Time: 1.32secs
#
# > Epoch: 80 [ 3744/18766 (20%)]
# > Epoch: 80 [ 7488/18766 (40%)]
# > Epoch: 80 [11232/18766 (60%)]
# > Epoch: 80 [14976/18766 (80%)]
# > Epoch: 80 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359894 	Time: 1.39secs
#
# > Epoch: 81 [ 3744/18766 (20%)]
# > Epoch: 81 [ 7488/18766 (40%)]
# > Epoch: 81 [11232/18766 (60%)]
# > Epoch: 81 [14976/18766 (80%)]
# > Epoch: 81 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359893 	Time: 1.49secs
#
# > Epoch: 82 [ 3744/18766 (20%)]
# > Epoch: 82 [ 7488/18766 (40%)]
# > Epoch: 82 [11232/18766 (60%)]
# > Epoch: 82 [14976/18766 (80%)]
# > Epoch: 82 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359892 	Time: 1.52secs
#
# > Epoch: 83 [ 3744/18766 (20%)]
# > Epoch: 83 [ 7488/18766 (40%)]
# > Epoch: 83 [11232/18766 (60%)]
# > Epoch: 83 [14976/18766 (80%)]
# > Epoch: 83 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359890 	Time: 1.33secs
#
# > Epoch: 84 [ 3744/18766 (20%)]
# > Epoch: 84 [ 7488/18766 (40%)]
# > Epoch: 84 [11232/18766 (60%)]
# > Epoch: 84 [14976/18766 (80%)]
# > Epoch: 84 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448394	Valid Loss: 0.359889 	Time: 1.49secs
#
# > Epoch: 85 [ 3744/18766 (20%)]
# > Epoch: 85 [ 7488/18766 (40%)]
# > Epoch: 85 [11232/18766 (60%)]
# > Epoch: 85 [14976/18766 (80%)]
# > Epoch: 85 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359888 	Time: 1.64secs
#
# > Epoch: 86 [ 3744/18766 (20%)]
# > Epoch: 86 [ 7488/18766 (40%)]
# > Epoch: 86 [11232/18766 (60%)]
# > Epoch: 86 [14976/18766 (80%)]
# > Epoch: 86 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359887 	Time: 1.73secs
#
# > Epoch: 87 [ 3744/18766 (20%)]
# > Epoch: 87 [ 7488/18766 (40%)]
# > Epoch: 87 [11232/18766 (60%)]
# > Epoch: 87 [14976/18766 (80%)]
# > Epoch: 87 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359886 	Time: 1.82secs
#
# > Epoch: 88 [ 3744/18766 (20%)]
# > Epoch: 88 [ 7488/18766 (40%)]
# > Epoch: 88 [11232/18766 (60%)]
# > Epoch: 88 [14976/18766 (80%)]
# > Epoch: 88 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359885 	Time: 1.50secs
#
# > Epoch: 89 [ 3744/18766 (20%)]
# > Epoch: 89 [ 7488/18766 (40%)]
# > Epoch: 89 [11232/18766 (60%)]
# > Epoch: 89 [14976/18766 (80%)]
# > Epoch: 89 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359884 	Time: 1.46secs
#
# > Epoch: 90 [ 3744/18766 (20%)]
# > Epoch: 90 [ 7488/18766 (40%)]
# > Epoch: 90 [11232/18766 (60%)]
# > Epoch: 90 [14976/18766 (80%)]
# > Epoch: 90 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359884 	Time: 1.43secs
#
# > Epoch: 91 [ 3744/18766 (20%)]
# > Epoch: 91 [ 7488/18766 (40%)]
# > Epoch: 91 [11232/18766 (60%)]
# > Epoch: 91 [14976/18766 (80%)]
# > Epoch: 91 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359883 	Time: 1.46secs
#
# > Epoch: 92 [ 3744/18766 (20%)]
# > Epoch: 92 [ 7488/18766 (40%)]
# > Epoch: 92 [11232/18766 (60%)]
# > Epoch: 92 [14976/18766 (80%)]
# > Epoch: 92 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359882 	Time: 1.40secs
#
# > Epoch: 93 [ 3744/18766 (20%)]
# > Epoch: 93 [ 7488/18766 (40%)]
# > Epoch: 93 [11232/18766 (60%)]
# > Epoch: 93 [14976/18766 (80%)]
# > Epoch: 93 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359881 	Time: 1.45secs
#
# > Epoch: 94 [ 3744/18766 (20%)]
# > Epoch: 94 [ 7488/18766 (40%)]
# > Epoch: 94 [11232/18766 (60%)]
# > Epoch: 94 [14976/18766 (80%)]
# > Epoch: 94 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359881 	Time: 1.44secs
#
# > Epoch: 95 [ 3744/18766 (20%)]
# > Epoch: 95 [ 7488/18766 (40%)]
# > Epoch: 95 [11232/18766 (60%)]
# > Epoch: 95 [14976/18766 (80%)]
# > Epoch: 95 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359880 	Time: 1.43secs
#
# > Epoch: 96 [ 3744/18766 (20%)]
# > Epoch: 96 [ 7488/18766 (40%)]
# > Epoch: 96 [11232/18766 (60%)]
# > Epoch: 96 [14976/18766 (80%)]
# > Epoch: 96 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359879 	Time: 1.49secs
#
# > Epoch: 97 [ 3744/18766 (20%)]
# > Epoch: 97 [ 7488/18766 (40%)]
# > Epoch: 97 [11232/18766 (60%)]
# > Epoch: 97 [14976/18766 (80%)]
# > Epoch: 97 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359879 	Time: 1.47secs
#
# > Epoch: 98 [ 3744/18766 (20%)]
# > Epoch: 98 [ 7488/18766 (40%)]
# > Epoch: 98 [11232/18766 (60%)]
# > Epoch: 98 [14976/18766 (80%)]
# > Epoch: 98 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448393	Valid Loss: 0.359878 	Time: 1.48secs
#
# > Epoch: 99 [ 3744/18766 (20%)]
# > Epoch: 99 [ 7488/18766 (40%)]
# > Epoch: 99 [11232/18766 (60%)]
# > Epoch: 99 [14976/18766 (80%)]
# > Epoch: 99 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448392	Valid Loss: 0.359877 	Time: 1.63secs
#
# > Epoch: 100 [ 3744/18766 (20%)]
# > Epoch: 100 [ 7488/18766 (40%)]
# > Epoch: 100 [11232/18766 (60%)]
# > Epoch: 100 [14976/18766 (80%)]
# > Epoch: 100 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448392	Valid Loss: 0.359877 	Time: 1.59secs
#
# > Epoch: 101 [ 3744/18766 (20%)]
# > Epoch: 101 [ 7488/18766 (40%)]
# > Epoch: 101 [11232/18766 (60%)]
# > Epoch: 101 [14976/18766 (80%)]
# > Epoch: 101 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448392	Valid Loss: 0.359876 	Time: 1.54secs
#
# > Epoch: 102 [ 3744/18766 (20%)]
# > Epoch: 102 [ 7488/18766 (40%)]
# > Epoch: 102 [11232/18766 (60%)]
# > Epoch: 102 [14976/18766 (80%)]
# > Epoch: 102 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448392	Valid Loss: 0.359876 	Time: 1.54secs
#
# > Epoch: 103 [ 3744/18766 (20%)]
# > Epoch: 103 [ 7488/18766 (40%)]
# > Epoch: 103 [11232/18766 (60%)]
# > Epoch: 103 [14976/18766 (80%)]
# > Epoch: 103 [18720/18766 (100%)]
#
# [INFO] Train Loss: 0.448392	Valid Loss: 0.359875 	Time: 1.57secs
#
# [INFO] Early stopping

# %% [markdown]
# ## Load optimized model

# %%
# Load best model
#
model.load_state_dict( torch.load( args.model_path ) );
model.eval();

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %%
device = 'cpu'
model.to( device )
# Out:
# Model(
#   (decompsition): series_decomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(25,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): Linear(in_features=96, out_features=96, bias=True)
#   (Linear_Trend): Linear(in_features=96, out_features=96, bias=True)
#   (Linear_Decoder): Linear(in_features=96, out_features=96, bias=True)
# )

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
pred = None
with torch.no_grad():
    for data, target in tqdm( test_dl ):

        data   = torch.tensor(data,   dtype=torch.float32)
        target = torch.tensor(target, dtype=torch.float32)

        if (pred is None):
            pred = model( data ).numpy()
        else:
            pred = np.concatenate([pred, model( data ).numpy()])
# Out:
# 100%|██████████| 162/162 [00:00<00:00, 682.50it/s]

# %%
# Reshaping...
#
testY = testY.squeeze(-1)
pred  = pred.squeeze(-1)

# %% [markdown]
# ### Apply inverse scaling/transformation

# %%
# Apply inverse scaling
#
for i in range( args.Horizon ):
    testY[:,  i] = scaler.inverse_transform( testY[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)


# Apply inverse transformation   
#
if (args.Transformation == True):
    testY = np.exp( testY ) - VALUE
    pred  = np.exp( pred )  - VALUE

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
import os

# %%
def save_metrics_to_file(model_name, target_col, metrics, horizon, H, window_complexity):
    """将评估指标保存到文件"""
    filename = "model_metrics.csv"
    
    # 检查文件是否存在,不存在则创建并写入表头
    if not os.path.exists(filename):
        with open(filename, "w") as f:
            f.write("model,target,mse,mae,rmse,horizon,H,window_complexity\n")
    
    # 添加新的评估结果
    with open(filename, "a") as f:
        f.write(f"{model_name},{target_col},{metrics['MSE']:.4f},{metrics['MAE']:.4f},"
                f"{metrics['RMSE']:.4f},{horizon},{H}, {window_complexity}\n")

# %%
print('[INFO] Feature: ', args.targetSeries)
print('------------------------------------------------')
Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : [], 'MSE': []}

for i in range( args.Horizon ):

    Prices = pd.DataFrame([])        

    Prices[ args.targetSeries ] = testY[:,i]
    Prices[ 'Prediction'      ] = pred[:,i]


    # Evaluation
    #
    MAE, RMSE, MAPE, SMAPE, R2, MSE = RegressionEvaluation( Prices )

    # Store results
    #
    Performance_Foresting_Model['RMSE']    += [ RMSE    ]
    Performance_Foresting_Model['MAE']     += [ MAE     ]
    # Performance_Foresting_Model['MAPE']    += [ MAPE    ]
    Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
    Performance_Foresting_Model['R2']      += [ R2      ]
    Performance_Foresting_Model['MSE']     += [ MSE     ]

    # Present results
    #
    print('Horizon: %2i MAE %5.2f RMSE %5.2f SMAPE: %5.2f R2: %.2f MSE: %.2f' % (i+1, MAE, RMSE, SMAPE, R2, MSE))
# Out:
# [INFO] Feature:  0
# ------------------------------------------------
# Horizon:  1 MAE  4.94 RMSE 10.37 SMAPE: 28.61 R2: 0.82 MSE: 107.51
# Horizon:  2 MAE  5.63 RMSE 11.41 SMAPE: 31.56 R2: 0.78 MSE: 130.12
# Horizon:  3 MAE  5.66 RMSE 11.53 SMAPE: 32.37 R2: 0.78 MSE: 133.00
# Horizon:  4 MAE  5.37 RMSE 11.34 SMAPE: 32.21 R2: 0.79 MSE: 128.65
# Horizon:  5 MAE  5.88 RMSE 11.92 SMAPE: 33.87 R2: 0.76 MSE: 142.04
# Horizon:  6 MAE  6.09 RMSE 12.19 SMAPE: 34.63 R2: 0.75 MSE: 148.64
# Horizon:  7 MAE  5.70 RMSE 11.90 SMAPE: 34.25 R2: 0.76 MSE: 141.70
# Horizon:  8 MAE  6.10 RMSE 12.35 SMAPE: 35.24 R2: 0.75 MSE: 152.63
# Horizon:  9 MAE  6.41 RMSE 12.71 SMAPE: 35.99 R2: 0.73 MSE: 161.43
# Horizon: 10 MAE  5.86 RMSE 12.19 SMAPE: 35.23 R2: 0.75 MSE: 148.67
# Horizon: 11 MAE  5.98 RMSE 12.42 SMAPE: 35.27 R2: 0.74 MSE: 154.24
# Horizon: 12 MAE  7.01 RMSE 13.40 SMAPE: 37.56 R2: 0.70 MSE: 179.63
# Horizon: 13 MAE  6.25 RMSE 12.77 SMAPE: 35.66 R2: 0.73 MSE: 163.12
# Horizon: 14 MAE  6.41 RMSE 12.95 SMAPE: 35.94 R2: 0.72 MSE: 167.78
# Horizon: 15 MAE  6.70 RMSE 13.25 SMAPE: 36.54 R2: 0.71 MSE: 175.60
# Horizon: 16 MAE  6.84 RMSE 13.41 SMAPE: 36.84 R2: 0.70 MSE: 179.82
# Horizon: 17 MAE  6.56 RMSE 13.19 SMAPE: 36.19 R2: 0.71 MSE: 174.08
# Horizon: 18 MAE  7.04 RMSE 13.67 SMAPE: 37.23 R2: 0.69 MSE: 186.78
# Horizon: 19 MAE  6.76 RMSE 13.44 SMAPE: 36.52 R2: 0.70 MSE: 180.59
# Horizon: 20 MAE  6.44 RMSE 13.17 SMAPE: 36.11 R2: 0.71 MSE: 173.57
# Horizon: 21 MAE  6.66 RMSE 13.40 SMAPE: 36.45 R2: 0.70 MSE: 179.64
# Horizon: 22 MAE  7.01 RMSE 13.75 SMAPE: 37.16 R2: 0.69 MSE: 189.12
# Horizon: 23 MAE  6.52 RMSE 13.31 SMAPE: 36.66 R2: 0.71 MSE: 177.05
# Horizon: 24 MAE  6.85 RMSE 13.64 SMAPE: 36.80 R2: 0.69 MSE: 185.97
# Horizon: 25 MAE  6.95 RMSE 13.75 SMAPE: 37.65 R2: 0.69 MSE: 188.94
# Horizon: 26 MAE  7.03 RMSE 13.84 SMAPE: 38.16 R2: 0.68 MSE: 191.60
# Horizon: 27 MAE  7.46 RMSE 14.28 SMAPE: 39.25 R2: 0.66 MSE: 204.06
# Horizon: 28 MAE  7.42 RMSE 14.29 SMAPE: 39.17 R2: 0.66 MSE: 204.11
# Horizon: 29 MAE  7.64 RMSE 14.53 SMAPE: 39.86 R2: 0.65 MSE: 211.07
# Horizon: 30 MAE  7.58 RMSE 14.49 SMAPE: 39.71 R2: 0.65 MSE: 209.91
# Horizon: 31 MAE  7.58 RMSE 14.50 SMAPE: 39.88 R2: 0.65 MSE: 210.31
# Horizon: 32 MAE  7.59 RMSE 14.51 SMAPE: 40.01 R2: 0.65 MSE: 210.60
# Horizon: 33 MAE  7.47 RMSE 14.40 SMAPE: 39.86 R2: 0.65 MSE: 207.42
# Horizon: 34 MAE  7.46 RMSE 14.41 SMAPE: 39.96 R2: 0.65 MSE: 207.53
# Horizon: 35 MAE  7.88 RMSE 14.86 SMAPE: 40.68 R2: 0.63 MSE: 220.85
# Horizon: 36 MAE  7.72 RMSE 14.71 SMAPE: 40.34 R2: 0.64 MSE: 216.40
# Horizon: 37 MAE  8.04 RMSE 15.08 SMAPE: 40.97 R2: 0.62 MSE: 227.39
# Horizon: 38 MAE  7.96 RMSE 15.01 SMAPE: 40.67 R2: 0.62 MSE: 225.40
# Horizon: 39 MAE  7.75 RMSE 14.80 SMAPE: 40.31 R2: 0.64 MSE: 219.16
# Horizon: 40 MAE  7.86 RMSE 14.93 SMAPE: 40.40 R2: 0.63 MSE: 222.88
# Horizon: 41 MAE  7.72 RMSE 14.78 SMAPE: 40.41 R2: 0.64 MSE: 218.38
# Horizon: 42 MAE  8.18 RMSE 15.32 SMAPE: 40.91 R2: 0.61 MSE: 234.77
# Horizon: 43 MAE  7.81 RMSE 14.90 SMAPE: 40.44 R2: 0.63 MSE: 221.91
# Horizon: 44 MAE  8.20 RMSE 15.37 SMAPE: 40.81 R2: 0.61 MSE: 236.24
# Horizon: 45 MAE  8.12 RMSE 15.28 SMAPE: 40.61 R2: 0.61 MSE: 233.54
# Horizon: 46 MAE  7.79 RMSE 14.83 SMAPE: 41.02 R2: 0.63 MSE: 220.05
# Horizon: 47 MAE  7.97 RMSE 15.09 SMAPE: 40.65 R2: 0.62 MSE: 227.75
# Horizon: 48 MAE  8.26 RMSE 15.46 SMAPE: 40.85 R2: 0.60 MSE: 239.10
# Horizon: 49 MAE  8.31 RMSE 15.52 SMAPE: 41.01 R2: 0.60 MSE: 240.81
# Horizon: 50 MAE  7.99 RMSE 15.06 SMAPE: 41.27 R2: 0.62 MSE: 226.79
# Horizon: 51 MAE  8.26 RMSE 15.45 SMAPE: 41.15 R2: 0.60 MSE: 238.72
# Horizon: 52 MAE  8.56 RMSE 15.84 SMAPE: 41.82 R2: 0.58 MSE: 250.82
# Horizon: 53 MAE  8.49 RMSE 15.74 SMAPE: 41.72 R2: 0.59 MSE: 247.69
# Horizon: 54 MAE  8.53 RMSE 15.79 SMAPE: 41.84 R2: 0.58 MSE: 249.38
# Horizon: 55 MAE  8.53 RMSE 15.79 SMAPE: 41.96 R2: 0.58 MSE: 249.39
# Horizon: 56 MAE  8.57 RMSE 15.83 SMAPE: 42.11 R2: 0.58 MSE: 250.49
# Horizon: 57 MAE  8.42 RMSE 15.61 SMAPE: 42.08 R2: 0.59 MSE: 243.72
# Horizon: 58 MAE  8.70 RMSE 16.00 SMAPE: 42.41 R2: 0.57 MSE: 255.96
# Horizon: 59 MAE  8.71 RMSE 16.02 SMAPE: 42.42 R2: 0.57 MSE: 256.70
# Horizon: 60 MAE  8.72 RMSE 16.04 SMAPE: 42.39 R2: 0.57 MSE: 257.40
# Horizon: 61 MAE  9.00 RMSE 16.43 SMAPE: 43.09 R2: 0.55 MSE: 269.89
# Horizon: 62 MAE  8.84 RMSE 16.23 SMAPE: 42.52 R2: 0.56 MSE: 263.26
# Horizon: 63 MAE  8.53 RMSE 15.75 SMAPE: 42.26 R2: 0.59 MSE: 248.18
# Horizon: 64 MAE  8.64 RMSE 15.93 SMAPE: 42.16 R2: 0.58 MSE: 253.61
# Horizon: 65 MAE  8.78 RMSE 16.15 SMAPE: 42.24 R2: 0.57 MSE: 260.92
# Horizon: 66 MAE  8.78 RMSE 16.16 SMAPE: 42.21 R2: 0.56 MSE: 261.20
# Horizon: 67 MAE  8.85 RMSE 16.26 SMAPE: 42.28 R2: 0.56 MSE: 264.37
# Horizon: 68 MAE  9.05 RMSE 16.55 SMAPE: 42.78 R2: 0.54 MSE: 273.82
# Horizon: 69 MAE  8.77 RMSE 16.14 SMAPE: 42.20 R2: 0.57 MSE: 260.46
# Horizon: 70 MAE  8.84 RMSE 16.24 SMAPE: 42.22 R2: 0.56 MSE: 263.88
# Horizon: 71 MAE  8.86 RMSE 16.27 SMAPE: 42.24 R2: 0.56 MSE: 264.66
# Horizon: 72 MAE  9.25 RMSE 16.84 SMAPE: 43.15 R2: 0.53 MSE: 283.64
# Horizon: 73 MAE  8.75 RMSE 16.04 SMAPE: 42.49 R2: 0.57 MSE: 257.17
# Horizon: 74 MAE  8.84 RMSE 16.19 SMAPE: 42.54 R2: 0.56 MSE: 262.16
# Horizon: 75 MAE  8.80 RMSE 16.06 SMAPE: 42.89 R2: 0.57 MSE: 258.03
# Horizon: 76 MAE  9.19 RMSE 16.75 SMAPE: 43.00 R2: 0.53 MSE: 280.60
# Horizon: 77 MAE  8.95 RMSE 16.34 SMAPE: 42.81 R2: 0.55 MSE: 267.15
# Horizon: 78 MAE  9.00 RMSE 16.43 SMAPE: 42.84 R2: 0.55 MSE: 269.86
# Horizon: 79 MAE  8.98 RMSE 16.36 SMAPE: 43.04 R2: 0.55 MSE: 267.56
# Horizon: 80 MAE  8.97 RMSE 16.31 SMAPE: 43.26 R2: 0.56 MSE: 265.92
# Horizon: 81 MAE  9.11 RMSE 16.58 SMAPE: 43.07 R2: 0.54 MSE: 274.96
# Horizon: 82 MAE  9.03 RMSE 16.39 SMAPE: 43.32 R2: 0.55 MSE: 268.73
# Horizon: 83 MAE  9.46 RMSE 17.15 SMAPE: 43.73 R2: 0.51 MSE: 294.22
# Horizon: 84 MAE  9.10 RMSE 16.52 SMAPE: 43.27 R2: 0.54 MSE: 272.93
# Horizon: 85 MAE  9.20 RMSE 16.74 SMAPE: 43.13 R2: 0.53 MSE: 280.15
# Horizon: 86 MAE  9.34 RMSE 16.98 SMAPE: 43.24 R2: 0.52 MSE: 288.32
# Horizon: 87 MAE  9.07 RMSE 16.21 SMAPE: 44.76 R2: 0.56 MSE: 262.74
# Horizon: 88 MAE  9.15 RMSE 16.55 SMAPE: 43.53 R2: 0.54 MSE: 273.81
# Horizon: 89 MAE  9.22 RMSE 16.73 SMAPE: 43.28 R2: 0.53 MSE: 279.89
# Horizon: 90 MAE  9.35 RMSE 16.99 SMAPE: 43.21 R2: 0.52 MSE: 288.58
# Horizon: 91 MAE  9.18 RMSE 16.53 SMAPE: 43.80 R2: 0.54 MSE: 273.18
# Horizon: 92 MAE  9.34 RMSE 16.94 SMAPE: 43.20 R2: 0.52 MSE: 287.07
# Horizon: 93 MAE  9.24 RMSE 16.68 SMAPE: 43.55 R2: 0.54 MSE: 278.17
# Horizon: 94 MAE  9.49 RMSE 17.22 SMAPE: 43.30 R2: 0.50 MSE: 296.58
# Horizon: 95 MAE  9.23 RMSE 16.51 SMAPE: 44.30 R2: 0.55 MSE: 272.42
# Horizon: 96 MAE  9.65 RMSE 17.48 SMAPE: 43.69 R2: 0.49 MSE: 305.39

# %%
metrics = {'MSE': MSE, 'MAE': MAE, 'RMSE': RMSE}
save_metrics_to_file(   model_name=args.model_name,
                        target_col=args.targetSeries,
                        metrics=metrics,
                        horizon=args.Horizon,
                        H = H,
                        window_complexity=window_complexity)
